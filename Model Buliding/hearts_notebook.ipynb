# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# - 'cp':'Chest Pain Type (CP)'
# - 'trestbps':'Resting Blood Pressure (trestbps)',
# - 'chol':'Serum Cholestoral (chol) mg/dl',
# - 'fbs':  'Fasting Blood Sugar (fbs) > 120 mg/dl',
# - 'restecg': 'Resting Electrocardiographic Results (restecg)',
# - 'thalach' : 'Maximum Heart Rate Achieved (thalach)',
# - 'exang': 'Exercise Induced Angina (exang)',
# - 'oldpeak' : 'ST depression (oldpeak)' ,
# - 'slope' : 'Slope of the ST Segment (slope)',
# - 'ca' : 'Number of Major Vessels (ca)',
# - 'thal' : 'Thal

# %%
df = pd.read_csv("heart_complete.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Histogram (for distribution)

# %%
df.hist(figsize=(12, 8))
plt.suptitle('Histograms of All Columns')
plt.show()

# %% [markdown]
# ### Boxplot (for outlier detection)

# %%
df.plot(kind='box', subplots=True, layout=(5, 3), figsize=(15, 12), sharex=False, sharey=False)
plt.suptitle('Boxplots of All Columns')
plt.show()

# %% [markdown]
# ### Scatter plot matrix (for relationships between variables)

# %%
scatter_matrix(df, figsize=(12, 12))
plt.suptitle('Scatter Matrix of All Columns')
plt.show()

# %% [markdown]
# ### Line plot

# %%
df.plot(kind='line', subplots=True, layout=(3, 3), figsize=(12, 10), sharex=False, sharey=False)
plt.suptitle('Line Plots of All Columns')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.plot(kind='line', subplots=True, layout=(3, 3), figsize=(12, 10), sharex=False, sharey=False)
#       2 plt.suptitle('Line Plots of All Columns')
#       3 plt.show()
#
# File c:\ProgramData\anaconda3\envs\ds_ml\lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\ProgramData\anaconda3\envs\ds_ml\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\ProgramData\anaconda3\envs\ds_ml\lib\site-packages\pandas\plotting\_matplotlib\core.py:500, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
#     499     self._compute_plot_data()
# --> 500     fig = self.fig
#     501     self._make_plot(fig)
#     502     self._add_table()
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\ProgramData\anaconda3\envs\ds_ml\lib\site-packages\pandas\plotting\_matplotlib\core.py:555, in MPLPlot.fig(self)
#     552 @final
#     553 @cache_readonly
#     554 def fig(self) -> Figure:
# --> 555     return self._axes_and_fig[1]
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\ProgramData\anaconda3\envs\ds_ml\lib\site-packages\pandas\plotting\_matplotlib\core.py:570, in MPLPlot._axes_and_fig(self)
#     566 if self.subplots:
#     567     naxes = (
#     568         self.nseries if isinstance(self.subplots, bool) else len(self.subplots)
#     569     )
# --> 570     fig, axes = create_subplots(
#     571         naxes=naxes,
#     572         sharex=self.sharex,
#     573         sharey=self.sharey,
#     574         figsize=self.figsize,
#     575         ax=self.ax,
#     576         layout=self.layout,
#     577         layout_type=self._layout_type,
#     578     )
#     579 elif self.ax is None:
#     580     fig = self.plt.figure(figsize=self.figsize)
#
# File c:\ProgramData\anaconda3\envs\ds_ml\lib\site-packages\pandas\plotting\_matplotlib\tools.py:276, in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     268         warnings.warn(
#     269             "To output multiple subplots, the figure containing "
#     270             "the passed axes is being cleared.",
#     271             UserWarning,
#     272             stacklevel=find_stack_level(),
#     273         )
#     274         fig.clear()
# --> 276 nrows, ncols = _get_layout(naxes, layout=layout, layout_type=layout_type)
#     277 nplots = nrows * ncols
#     279 # Create empty object array to hold all axes.  It's easiest to make it 1-d
#     280 # so we can just append subplots upon creation, and then
#
# File c:\ProgramData\anaconda3\envs\ds_ml\lib\site-packages\pandas\plotting\_matplotlib\tools.py:112, in _get_layout(nplots, layout, layout_type)
#     109         raise ValueError(msg)
#     111     if nrows * ncols < nplots:
# --> 112         raise ValueError(
#     113             f"Layout of {nrows}x{ncols} must be larger than required size {nplots}"
#     114         )
#     116     return layout
#     118 if layout_type == "single":
#
# ValueError: Layout of 3x3 must be larger than required size 14

# %% [markdown]
# ### Bar plot

# %%
df.plot(kind='bar', subplots=True, layout=(3, 3), figsize=(12, 10), sharex=False, sharey=False)
plt.suptitle('Bar Plots of All Columns')
plt.show()

# %% [markdown]
# ### Correlation heatmap (to show relationships between columns)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of All Columns')
plt.show()

# %% [markdown]
# ### Data modeling

# %%
X = df.drop(columns=['target'])
y = df['target']
# Feature scaling (Standardizing the data)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)
X_train, X_test, y_train, y_test = train_test_split(X_resampled,y_resampled,test_size= 0.2)

# %%
# Display the class distribution before and after resampling
print(f"Original dataset shape: {np.bincount(y)}")
print(f"Resampled dataset shape: {np.bincount(y_resampled)}")
# Out:
# Original dataset shape: [499 526]
# Resampled dataset shape: [526 526]

# %%
### Logistic Regression
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8578
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86       109
#            1       0.83      0.89      0.86       102
#
#     accuracy                           0.86       211
#    macro avg       0.86      0.86      0.86       211
# weighted avg       0.86      0.86      0.86       211

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
y_pred = dt.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9953
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       109
#            1       0.99      1.00      1.00       102
#
#     accuracy                           1.00       211
#    macro avg       1.00      1.00      1.00       211
# weighted avg       1.00      1.00      1.00       211

# %%
svm = SVC()
svm.fit(X_train,y_train)
y_pred = svm.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9336
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       109
#            1       0.93      0.93      0.93       102
#
#     accuracy                           0.93       211
#    macro avg       0.93      0.93      0.93       211
# weighted avg       0.93      0.93      0.93       211

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8436
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       109
#            1       0.85      0.82      0.84       102
#
#     accuracy                           0.84       211
#    macro avg       0.84      0.84      0.84       211
# weighted avg       0.84      0.84      0.84       211

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
y_pred = rfc.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       109
#            1       1.00      1.00      1.00       102
#
#     accuracy                           1.00       211
#    macro avg       1.00      1.00      1.00       211
# weighted avg       1.00      1.00      1.00       211

# %%
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees
    'max_depth': [10, 20, 30, None],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split
    'min_samples_leaf': [1, 2, 4],    # Minimum samples required at a leaf node
    'max_features': ['sqrt', 'log2', None]  # Number of features to consider at each split
}

rfc = RandomForestClassifier(random_state=42)

grid_search = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
print(f"Best Hyperparameters: {best_params}")

best_rfc = grid_search.best_estimator_
y_pred = best_rfc.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best Hyperparameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       109
#            1       1.00      1.00      1.00       102
#
#     accuracy                           1.00       211
#    macro avg       1.00      1.00      1.00       211
# weighted avg       1.00      1.00      1.00       211
